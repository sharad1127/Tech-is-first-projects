# %%
def mad_lib1():
  animals=input('enter a animal name : ')
  profession=input('enter a profession : ')
  cloth=input('enter a piece of cloth name : ')
  things=input('enter a thing name : ')
  name=input('enter a any name : ')
  place=input('enter a place name : ')
  verb=input('enter a verb : ')
  food=input('enter a foods name : ')

  print('say ' + food + ', the photographer said as the camera flashed! ' + name + ' and I had gone to ' + place +
              ' to get our photos taken on my birthday. The first photo we really wanted was a picture of us dressed as ' + 
              animals + ' pretending to be a ' + profession + '. when we saw the second photo, it was exactly what I wanted. We both looked like ' + 
              things + ' wearing ' + cloth + ' and ' + verb + ' --exactly what I had in mind')
  
def mad_lib2():
  adjectives=input('enter a adjective : ')
  color=input('enter a color : ')
  things=input('enter a thing name : ')
  place=input('enter a place name : ')
  person=input('enter a persons name : ')
  insect=input('enter a insect name : ')
  food=input('enter a food name : ')

  print('say ' + food + ', the photographer said as the camera flashed! ' + ' and I had gone to ' + place +
              ' to get our photos taken on my birthday. The first photo we really wanted was a picture of us dressed as ' + 
              food + ' pretending to be a ' + adjectives + '. when we saw the second photo, it was exactly what I wanted. We both looked like ' + 
              things + ' wearing ' + color + ' and ' + insect + ' --exactly what I had in mind')
  
def mad_lib3():
  person=input('enter a persons name : ')
  color=input('enter a color : ')
  foods=input('enter a food name : ')
  verb=input('a verb : ')
  things=input('a things name : ')

  print('say ' + ', my name is '+ person + 'the favorite color of the person is '+ color + 'the favorite food is '+ foods + 'the verb he uses is '+ 
        
        verb + ' he likes the things '+things)

# %%
mad_lib1()
mad_lib2()
mad_lib3()
# Out:
# enter a animal name : Dog
# enter a profession : Web development
# enter a piece of cloth name : shirt
# enter a thing name : Car
# enter a any name : joe
# enter a place name : karnataka
# enter a verb : hey
# enter a foods name : rice
# say rice, the photographer said as the camera flashed! joe and I had gone to karnataka to get our photos taken on my birthday. The first photo we really wanted was a picture of us dressed as Dog pretending to be a Web development. when we saw the second photo, it was exactly what I wanted. We both looked like Car wearing shirt and hey --exactly what I had in mind
# enter a adjective : sos
# enter a color : red
# enter a thing name : Bike
# enter a place name : tokyo
# enter a persons name : kona
# enter a insect name : Bug
# enter a food name : Bread
# ...
