# %%
import random

# %%
signs_player1=input('Enter a choice(rock,paper,scisors): ')
signs_player2=input('Enter a choice(rock,paper,scisors): ')


print(f"\nplayer1 :{signs_player1}, player2 :{signs_player2}.\n")
if signs_player1==signs_player2
  print('Both players selected{signs_player1}.its a tie')

elif signs_player1=='rock':
  if signs_player2=='scisors':
    print('rock smashes scisors you win')
  else:
    print('paper covers rocks you lose')

elif signs_player1=='paper':
  if signs_player2=='rock':
    print('papers covers rocks you win')
  else:
    print('scisors cut paper you lose')
  
elif signs_player1=='scisor':
  if signs_player2=='paper':
    print('scisors cut papers you win')
  else:
    print('rock smashes scisors you lose')
# Out:
# Enter a choice(rock,paper,scisors): scisor
# Enter a choice(rock,paper,scisors): paper
#
# player1 :scisor, player2 :paper.
#
# scisors cut papers you win
